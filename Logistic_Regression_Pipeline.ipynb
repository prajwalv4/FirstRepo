# %% [markdown]
# <a href="https://colab.research.google.com/github/prajwalv4/FirstRepo/blob/main/Logistic_Regression_Pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#IMPORTING THE LIBRARIES
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#IMPORTING THE DATASET
df=pd.read_csv('/content/Wine.csv')

# %%
#data preprocessing
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Alcohol               178 non-null    float64
#  1   Malic_Acid            178 non-null    float64
#  2   Ash                   178 non-null    float64
#  3   Ash_Alcanity          178 non-null    float64
#  4   Magnesium             178 non-null    int64
#  5   Total_Phenols         178 non-null    float64
#  6   Flavanoids            178 non-null    float64
#  7   Nonflavanoid_Phenols  178 non-null    float64
#  8   Proanthocyanins       178 non-null    float64
#  9   Color_Intensity       178 non-null    float64
#  10  Hue                   178 non-null    float64
#  11  OD280                 178 non-null    float64
#  12  Proline               178 non-null    int64
#  13  Customer_Segment      178 non-null    int64
# dtypes: float64(11), int64(3)
# ...

# %%
df.isnull().sum()
# Out:
# Alcohol                 0
# Malic_Acid              0
# Ash                     0
# Ash_Alcanity            0
# Magnesium               0
# Total_Phenols           0
# Flavanoids              0
# Nonflavanoid_Phenols    0
# Proanthocyanins         0
# Color_Intensity         0
# Hue                     0
# OD280                   0
# Proline                 0
# Customer_Segment        0
# dtype: int64

# %%
df["Customer_Segment"].value_counts()
# Out:
# Customer_Segment
# 2    71
# 1    59
# 3    48
# Name: count, dtype: int64

# %%
#Assign the X and Y values
#X=df.iloc[ROWS,COLUMNS].values
X=df.iloc[:,:-1].values

# %%
y=df.iloc[:,-1].values

# %%
#split the dataset
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=2)

# %%
#standardization
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
#pca analysis
from sklearn.decomposition import PCA
pca=PCA(n_components=2)

# %%
X_train=pca.fit_transform(X_train)

# %%
X_test=pca.transform(X_test)

# %%
X_train
# Out:
# array([[-2.60961019,  0.46358725],
#        [ 0.93679893, -1.37376221],
#        [-0.3811003 , -2.59922532],
#        [-1.83128734, -1.51621319],
#        [-2.83839012,  1.97485438],
#        [-2.032136  ,  1.28739621],
#        [ 0.53905795, -0.99191144],
#        [ 4.29842704,  2.42704849],
#        [-2.49081168,  0.79810751],
#        [-0.35530306, -2.20599964],
#        [-1.63961375, -1.1596748 ],
#        [ 2.23034247,  0.08203728],
#        [-2.18841657,  2.4672434 ],
#        [ 2.38673447, -1.70992023],
#        [-0.30813392, -0.66464469],
#        [-1.43066062, -1.25789936],
#        [ 1.75568892, -1.39162697],
#        [ 0.95649013, -1.84888331],
#        [ 1.56467997, -2.09789751],
#        [-2.25042211,  0.5118994 ],
#        [-1.54975301,  2.45613855],
#        [ 2.21523999,  1.47767881],
#        [ 1.78156562, -0.78665163],
#        [-3.06208366, -0.17482487],
#        [-2.32723433, -1.1970787 ],
#        [-2.18977067,  0.51042709],
#        [-3.48714311,  1.30502989],
# ...

# %%
X_test
# Out:
# array([[-2.60961019,  0.46358725],
#        [ 0.93679893, -1.37376221],
#        [-0.3811003 , -2.59922532],
#        [-1.83128734, -1.51621319],
#        [-2.83839012,  1.97485438],
#        [-2.032136  ,  1.28739621],
#        [ 0.53905795, -0.99191144],
#        [ 4.29842704,  2.42704849],
#        [-2.49081168,  0.79810751],
#        [-0.35530306, -2.20599964],
#        [-1.63961375, -1.1596748 ],
#        [ 2.23034247,  0.08203728],
#        [-2.18841657,  2.4672434 ],
#        [ 2.38673447, -1.70992023],
#        [-0.30813392, -0.66464469],
#        [-1.43066062, -1.25789936],
#        [ 1.75568892, -1.39162697],
#        [ 0.95649013, -1.84888331],
#        [ 1.56467997, -2.09789751],
#        [-2.25042211,  0.5118994 ],
#        [-1.54975301,  2.45613855],
#        [ 2.21523999,  1.47767881],
#        [ 1.78156562, -0.78665163],
#        [-3.06208366, -0.17482487],
#        [-2.32723433, -1.1970787 ],
#        [-2.18977067,  0.51042709],
#        [-3.48714311,  1.30502989],
# ...

# %%
#fitting Logistic Regression
from sklearn.linear_model import LogisticRegression
lor=LogisticRegression()

# %%
lor.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
#predicting the model
y_pred=lor.predict(X_test)

# %%
#model metrics
from sklearn.metrics import confusion_matrix,accuracy_score

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-446449224.py in <cell line: 0>()
# ----> 1 print(confusion_matrix(y_test,y_pred))
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     214                     )
#     215                 ):
# --> 216                     return func(*args, **kwargs)
#     217             except InvalidParameterError as e:
#     218                 # When the function is just a wrapper around an estimator, we allow
#
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     338     """
#     339     y_true, y_pred = attach_unique(y_true, y_pred)
# --> 340     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     341     if y_type not in ("binary", "multiclass"):
# ...
